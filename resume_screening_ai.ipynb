# %%
# Import libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Sample resumes
resumes = [
    "Python developer with machine learning and NLP experience",
    "Frontend developer skilled in React and CSS",
    "Data scientist with deep learning and Python",
    "Java backend developer with Spring Boot",
    "Basic computer knowledge and MS Office"
]

# Job description
job_description = "Looking for a Python developer with machine learning and NLP skills"

# Combine data
documents = resumes + [job_description]

# Convert text to vectors
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(documents)

# Compute similarity
similarity = cosine_similarity(vectors)

# Compare resumes with job description
scores = similarity[-1][:-1]

# Display results
for i, score in enumerate(scores):
    print(f"Resume {i+1} Match Score: {round(score*100, 2)}%")

    if score > 0.3:
        print("Selected ✅")
    else:
        print("Not Selected ❌")

    print("-" * 40)

#Find top candidate
best_index = scores.argmax()
print("🏆 Top Candidate Selected:")
print(resumes[best_index])
print(f"Match Score: {round(scores[best_index]*100, 2)}%")
# Out:
# Resume 1 Match Score: 63.2%
# Selected ✅
# ----------------------------------------
# Resume 2 Match Score: 10.36%
# Not Selected ❌
# ----------------------------------------
# Resume 3 Match Score: 29.38%
# Not Selected ❌
# ----------------------------------------
# Resume 4 Match Score: 12.96%
# Not Selected ❌
# ----------------------------------------
# Resume 5 Match Score: 4.57%
# Not Selected ❌
# ----------------------------------------
# 🏆 Top Candidate Selected:
# Python developer with machine learning and NLP experience
# Match Score: 63.2%
